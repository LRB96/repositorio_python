# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("../Desktop/ciencias_datos/DATASETS/human_resources/HRDataset_v14.csv")
df=df.rename(columns=str.lower)
df.head()
# Out:
#               employee_name  empid  marriedid  maritalstatusid  genderid  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    empstatusid  deptid  perfscoreid  fromdiversityjobfairid  salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       managername  managerid recruitmentsource performancescore  \
# ...

# %%
df["sex"]
# Out:
# 0      M
# 1      M
# 2       F
# 3       F
# 4       F
#        ..
# 306    M
# 307     F
# 308     F
# 309     F
# 310     F
# Name: sex, Length: 311, dtype: object

# %%
#dummy_sex=pd.get_dummies(df["sex"],prefix="sexo")
#dummy_sex.head()

# %%
#df=df.drop(["sexo],axis=1)
#df.head()

# %%
df.shape
# Out:
# (311, 35)

# %%
dummy_sex.shape
# Out:
# (311, 2)

# %%
df_2=pd.concat([df,dummy_sex],axis=1)
df_2.head()
# Out:
#               employee_name  empid  marriedid  maritalstatusid  genderid  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    empstatusid  deptid  perfscoreid  fromdiversityjobfairid  salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    recruitmentsource  performancescore engagementsurvey empsatisfaction  \
# ...

# %%
df_2["citizendesc"]
# Out:
# 0      US Citizen
# 1      US Citizen
# 2      US Citizen
# 3      US Citizen
# 4      US Citizen
#           ...
# 306    US Citizen
# 307    US Citizen
# 308    US Citizen
# 309    US Citizen
# 310    US Citizen
# Name: citizendesc, Length: 311, dtype: object

# %%
df_2.shape
# Out:
# (311, 37)

# %%
df_2.columns
# Out:
# Index(['employee_name', 'empid', 'marriedid', 'maritalstatusid', 'genderid',
#        'empstatusid', 'deptid', 'perfscoreid', 'fromdiversityjobfairid',
#        'salary', 'termd', 'positionid', 'position', 'state', 'zip', 'dob',
#        'maritaldesc', 'citizendesc', 'hispaniclatino', 'racedesc',
#        'dateofhire', 'dateoftermination', 'termreason', 'employmentstatus',
#        'department', 'managername', 'managerid', 'recruitmentsource',
#        'performancescore', 'engagementsurvey', 'empsatisfaction',
#        'specialprojectscount', 'lastperformancereview_date', 'dayslatelast30',
#        'absences', 'sexo_F', 'sexo_M '],
#       dtype='object')

# %%
def creatdummies(df,varname):
    dummy=df.get_dummies([varname],prefix=varname)
    df=df.drop(varname,axis=1)
    df=pd.concat([df,dummy],axis=1)
    return df

# %%
createdummies(df_2,"citizendesc")
# Out:
#                 employee_name  empid  marriedid  maritalstatusid  genderid  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...
