# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)
y=x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,"rx")
plt.show()

# %%
plt.plot(x,y,"bo")
plt.show()

# %%
plt.plot(x,y,"rs-")
plt.show()

# %%
plt.plot(x,y,"yD:")
plt.show()

# %%
plt.hist(x,y)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.boxplot(x);
