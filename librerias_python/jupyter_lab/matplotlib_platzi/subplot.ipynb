# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
plt.subplot(2,1,1)
plt.plot(x,y,"r--")
plt.plot(y,x,"b:")
plt.subplot(2,1,2)
plt.scatter(y,x)
plt.scatter(x,y);
