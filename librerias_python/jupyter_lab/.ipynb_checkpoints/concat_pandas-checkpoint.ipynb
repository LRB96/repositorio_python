# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(filepath_or_buffer="../DATASETS/human_resources/HRDataset_v14.csv").rename(columns=str.lower)
df.head()
# Out:
#               employee_name  empid  marriedid  maritalstatusid  genderid  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    empstatusid  deptid  perfscoreid  fromdiversityjobfairid  salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       managername  managerid recruitmentsource performancescore  \
# ...

# %%
df1=df[["employee_name","salary","performancescore","engagementsurvey"]]

# %%
df1
# Out:
#                 employee_name  salary performancescore  engagementsurvey
# 0         Adinolfi, Wilson  K   62506          Exceeds              4.60
# 1    Ait Sidi, Karthikeyan     104437      Fully Meets              4.96
# 2           Akinkuolie, Sarah   64955      Fully Meets              3.02
# 3                Alagbe,Trina   64991      Fully Meets              4.84
# 4            Anderson, Carol    50825      Fully Meets              5.00
# ..                        ...     ...              ...               ...
# 306            Woodson, Jason   65893      Fully Meets              4.07
# 307        Ybarra, Catherine    48513              PIP              3.20
# 308          Zamora, Jennifer  220450          Exceeds              4.60
# 309               Zhou, Julia   89292      Fully Meets              5.00
# 310             Zima, Colleen   45046      Fully Meets              4.50
#
# [311 rows x 4 columns]

# %%
df1=df1.iloc[7:12]
df1
# Out:
# Empty DataFrame
# Columns: [employee_name, salary, performancescore, engagementsurvey]
# Index: []

# %%
df1
# Out:
# Empty DataFrame
# Columns: [employee_name, salary, performancescore, engagementsurvey]
# Index: []

# %%
df5=pd.concat([df,df1],axis=1)

# %%
df5
# Out:
#                 employee_name  empid  marriedid  maritalstatusid  genderid  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...
