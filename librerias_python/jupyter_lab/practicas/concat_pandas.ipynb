# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(filepath_or_buffer=("./HRDataset_v14.csv"),sep=",",header=0).rename(columns=str.lower)
df
# Out:
#                 employee_name  empid  marriedid  maritalstatusid  genderid  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
df1=df[["employee_name","salary","performancescore","engagementsurvey"]]

# %%
df1.head()
# Out:
#               employee_name  salary performancescore  engagementsurvey
# 0       Adinolfi, Wilson  K   62506          Exceeds              4.60
# 1  Ait Sidi, Karthikeyan     104437      Fully Meets              4.96
# 2         Akinkuolie, Sarah   64955      Fully Meets              3.02
# 3              Alagbe,Trina   64991      Fully Meets              4.84
# 4          Anderson, Carol    50825      Fully Meets              5.00

# %%
df1.loc[:,"employee_name":"performancescore"].head()
# Out:
#               employee_name  salary performancescore
# 0       Adinolfi, Wilson  K   62506          Exceeds
# 1  Ait Sidi, Karthikeyan     104437      Fully Meets
# 2         Akinkuolie, Sarah   64955      Fully Meets
# 3              Alagbe,Trina   64991      Fully Meets
# 4          Anderson, Carol    50825      Fully Meets

# %%
df1.iloc[:,[1,2]].head()
# Out:
#    salary performancescore
# 0   62506          Exceeds
# 1  104437      Fully Meets
# 2   64955      Fully Meets
# 3   64991      Fully Meets
# 4   50825      Fully Meets

# %%
df1.head()
# Out:
#               employee_name  salary performancescore  engagementsurvey
# 0       Adinolfi, Wilson  K   62506          Exceeds              4.60
# 1  Ait Sidi, Karthikeyan     104437      Fully Meets              4.96
# 2         Akinkuolie, Sarah   64955      Fully Meets              3.02
# 3              Alagbe,Trina   64991      Fully Meets              4.84
# 4          Anderson, Carol    50825      Fully Meets              5.00

# %%
#Siempre para concatenar hay que establecer el eje por cual se hace.
#Eje 0 para filas, y eje 1 para columnas
#Siempre los df se ponen entre corchetes, como una lista
df2=pd.concat([df,df1],axis=1)

# %%
df2
# Out:
#                 employee_name  empid  marriedid  maritalstatusid  genderid  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...
