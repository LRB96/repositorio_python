# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(filepath_or_buffer="./players_20.csv",sep=",",header=0).rename(columns=str.lower)
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
df.shape
# Out:
# (18278, 104)

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
df1=df[["short_name","age","height_cm","weight_kg","nationality","club","overall","potential","value_eur","wage_eur","player_positions","power_jumping","power_long_shots"]]
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
df1.shape
# Out:
# (18278, 13)

# %%
df1.sort_values("overall",ascending=False).head()
# Out:
#           short_name  age  height_cm  weight_kg nationality  \
# 0           L. Messi   32        170         72   Argentina
# 1  Cristiano Ronaldo   34        187         83    Portugal
# 2          Neymar Jr   27        175         68      Brazil
# 3           J. Oblak   26        188         87    Slovenia
# 4          E. Hazard   28        175         74     Belgium
#
#                   club  overall  potential  value_eur  wage_eur  \
# 0         FC Barcelona       94         94   95500000    565000
# 1             Juventus       93         93   58500000    405000
# 2  Paris Saint-Germain       92         92  105500000    290000
# 3      Atlético Madrid       91         93   77500000    125000
# 4          Real Madrid       91         91   90000000    470000
#
#   player_positions  power_jumping  power_long_shots
# 0       RW, CF, ST             68                94
# 1           ST, LW             95                93
# 2          LW, CAM             61                84
# ...

# %%
#Sigue aqquí
realmadrid=df1[df1.club=="Real Madrid"]
realmadrid.shape
# Out:
# (33, 13)

# %%
realmadrid.sort_values("overall",ascending=False)
# Out:
#             short_name  age  height_cm  weight_kg         nationality  \
# 4            E. Hazard   28        175         74             Belgium
# 8            L. Modrić   33        172         66             Croatia
# 18        Sergio Ramos   33        184         82               Spain
# 28         T. Courtois   27        199         96             Belgium
# 36            T. Kroos   29        183         76             Germany
# 42            Casemiro   27        185         84              Brazil
# 46          K. Benzema   31        185         81              France
# 53            K. Navas   32        185         80          Costa Rica
# 62                Isco   27        176         79               Spain
# 76           R. Varane   26        191         81              France
# 94            Carvajal   27        173         73               Spain
# 100            G. Bale   29        185         82               Wales
# ...

# %%
realmadrid.sort_values("value_eur",ascending=False)
# Out:
#             short_name  age  height_cm  weight_kg         nationality  \
# 4            E. Hazard   28        175         74             Belgium
# 36            T. Kroos   29        183         76             Germany
# 42            Casemiro   27        185         84              Brazil
# 62                Isco   27        176         79               Spain
# 28         T. Courtois   27        199         96             Belgium
# 8            L. Modrić   33        172         66             Croatia
# 76           R. Varane   26        191         81              France
# 46          K. Benzema   31        185         81              France
# 106       J. Rodríguez   27        180         75            Colombia
# 94            Carvajal   27        173         73               Spain
# 100            G. Bale   29        185         82               Wales
# 161           L. Jović   21        182         85              Serbia
# ...

# %%
#Para renombrar columnas se ponen entre llaves, y 2 puntos en medio.
realmadrid.rename(columns={"age":"edad"}).head()
# Out:
#       short_name  edad  height_cm  weight_kg nationality         club  \
# 4      E. Hazard    28        175         74     Belgium  Real Madrid
# 8      L. Modrić    33        172         66     Croatia  Real Madrid
# 18  Sergio Ramos    33        184         82       Spain  Real Madrid
# 28   T. Courtois    27        199         96     Belgium  Real Madrid
# 36      T. Kroos    29        183         76     Germany  Real Madrid
#
#     overall  potential  value_eur  wage_eur player_positions  power_jumping  \
# 4        91         91   90000000    470000           LW, CF             56
# 8        90         90   45000000    340000               CM             68
# 18       89         89   31500000    300000               CB             93
# 28       88         89   48000000    235000               GK             68
# 36       88         88   57000000    330000               CM             30
#
#     power_long_shots
# 4                 80
# 8                 82
# ...

# %%
realmadrid.rename(columns={"height_cm":"altura_cm"}).head()
# Out:
#       short_name  age  altura_cm  weight_kg nationality         club  overall  \
# 4      E. Hazard   28        175         74     Belgium  Real Madrid       91
# 8      L. Modrić   33        172         66     Croatia  Real Madrid       90
# 18  Sergio Ramos   33        184         82       Spain  Real Madrid       89
# 28   T. Courtois   27        199         96     Belgium  Real Madrid       88
# 36      T. Kroos   29        183         76     Germany  Real Madrid       88
#
#     potential  value_eur  wage_eur player_positions  power_jumping  \
# 4          91   90000000    470000           LW, CF             56
# 8          90   45000000    340000               CM             68
# 18         89   31500000    300000               CB             93
# 28         89   48000000    235000               GK             68
# 36         88   57000000    330000               CM             30
#
#     power_long_shots
# 4                 80
# 8                 82
# 18                62
# ...

# %%
realmadrid.rename(columns={"players_positions":"posicion"}).head()
# Out:
#       short_name  age  height_cm  weight_kg nationality         club  overall  \
# 4      E. Hazard   28        175         74     Belgium  Real Madrid       91
# 8      L. Modrić   33        172         66     Croatia  Real Madrid       90
# 18  Sergio Ramos   33        184         82       Spain  Real Madrid       89
# 28   T. Courtois   27        199         96     Belgium  Real Madrid       88
# 36      T. Kroos   29        183         76     Germany  Real Madrid       88
#
#     potential  value_eur  wage_eur player_positions  power_jumping  \
# 4          91   90000000    470000           LW, CF             56
# 8          90   45000000    340000               CM             68
# 18         89   31500000    300000               CB             93
# 28         89   48000000    235000               GK             68
# 36         88   57000000    330000               CM             30
#
#     power_long_shots
# 4                 80
# 8                 82
# 18                62
# ...

# %%
realmadrid[realmadrid.weight_kg>80]
# Out:
#          short_name  age  height_cm  weight_kg nationality         club  \
# 18     Sergio Ramos   33        184         82       Spain  Real Madrid
# 28      T. Courtois   27        199         96     Belgium  Real Madrid
# 42         Casemiro   27        185         84      Brazil  Real Madrid
# 46       K. Benzema   31        185         81      France  Real Madrid
# 76        R. Varane   26        191         81      France  Real Madrid
# 100         G. Bale   29        185         82       Wales  Real Madrid
# 161        L. Jović   21        182         85      Serbia  Real Madrid
# 13116        Altube   19        188         85       Spain  Real Madrid
#
#        overall  potential  value_eur  wage_eur player_positions  \
# 18          89         89   31500000    300000               CB
# 28          88         89   48000000    235000               GK
# 42          87         89   53500000    240000              CDM
# ...

# %%
#Crea una muestra aleatoria
#Porcentaje 10%
realmadrid.sample(frac=0.1)
# Out:
#         short_name  age  height_cm  weight_kg nationality         club  \
# 8777  Sergio López   20        179         66       Spain  Real Madrid
# 46      K. Benzema   31        185         81      France  Real Madrid
# 36        T. Kroos   29        183         76     Germany  Real Madrid
#
#       overall  potential  value_eur  wage_eur player_positions  power_jumping  \
# 8777       66         82    1300000     20000               RB             61
# 46         87         87   45000000    285000           CF, ST             77
# 36         88         88   57000000    330000               CM             30
#
#       power_long_shots
# 8777                59
# 46                  76
# 36                  86

# %%
#Valor absoluto 5 unidades
realmadrid.sample(n=5)
# Out:
#         short_name  age  height_cm  weight_kg nationality         club  \
# 1256       Rodrygo   18        174         64      Brazil  Real Madrid
# 46      K. Benzema   31        185         81      France  Real Madrid
# 8777  Sergio López   20        179         66       Spain  Real Madrid
# 94        Carvajal   27        173         73       Spain  Real Madrid
# 76       R. Varane   26        191         81      France  Real Madrid
#
#       overall  potential  value_eur  wage_eur player_positions  power_jumping  \
# 1256       76         89   14000000     47000       LW, RW, ST             73
# 46         87         87   45000000    285000           CF, ST             77
# 8777       66         82    1300000     20000               RB             61
# 94         85         86   38000000    205000               RB             77
# 76         85         90   45000000    205000               CB             79
#
#       power_long_shots
# 1256                70
# ...
