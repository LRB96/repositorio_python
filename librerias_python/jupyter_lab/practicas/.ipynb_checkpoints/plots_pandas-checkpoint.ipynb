# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df =pd.read_csv("air_quality_no2.csv",index_col=0,parse_dates=True)
print(df)
df.plot.scatter(x="station_london",y="station_paris",alpha=0.5)
df.plot.area(x="station_london",y="station_paris",alpha=0.5)
plt.show()
[
    method_name
    for method_name in dir(df.plot)
    if not method_name.startswith("_")
]
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
# ...

# %% [markdown]
# df.plot.bar(x="station_london",y="station_paris",alpha=0.5)
# df.plot.barh(x="station_london",y="station_paris",alpha=0.5)
# df.plot.box(x="station_london",y="station_paris",alpha=0.5)
# df.plot.density(x="station_london",y="station_paris",alpha=0.5)
# df.plot.hexbin(x="station_london",y="station_paris",alpha=0.5)
# df.plot.hist(x="station_london",y="station_paris",alpha=0.5)
# df.plot.kde(x="station_london",y="station_paris",alpha=0.5)
# df.plot.line(x="station_london",y="station_paris",alpha=0.5)
# df.plot.pie(x="staion_london",y="station_paris",alpha=0.5)
#
# df.plot.bar()
# df.plot.barh()
# df.plot.box()
# df.plot.density()
# df.plot.hexbin()
# df.plot.hist()
# df.plot.kde()
# df.plot.line()
# df.plot.pie()

# %%
df.plot.box()
plt.show()

# %%
df.plot.area(figsize=(12,4),subplots=True)
plt.show()

# %%
fig,axs = plt.subplots(figsize=(12,4))
df.plot.area(ax=axs)
axs.set_ylabel("NO$_2$ concentration")
fig.savefig("no2_concentration")
plt.show()

# %%
df["london_mg_per_cubic"] = df["station_london"]*1.882
print(df)
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# ...

# %%
df["ratio_paris_antwerp"] = (df["station_paris"] / df["station_antwerp"])
df
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# ...

# %%
df_renamed = df.rename(columns={"station_antwerp":"BETR801",
                                "station_paris":"FR04014",
                                "station_london":"London Westminster",
                               })
df_renamed
# Out:
#                      BETR801  FR04014  London Westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
# ...                      ...      ...                 ...
# 2019-06-20 22:00:00      NaN     21.4                 NaN
# 2019-06-20 23:00:00      NaN     24.9                 NaN
# 2019-06-21 00:00:00      NaN     26.5                 NaN
# 2019-06-21 01:00:00      NaN     21.8                 NaN
# 2019-06-21 02:00:00      NaN     20.0                 NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# 2019-05-07 03:00:00               35.758             0.495050
# ...

# %%
df_renamed = df.rename(columns=str.lower)
df_renamed
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
#                                                                                                                                         titanic.csv

# %%
df =pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = df.rename(columns=str.lower)
df
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["age"].mean()
# Out:
# 29.69911764705882

# %%
df[["age","fare"]].describe()
# Out:
#               age        fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
df[["age","fare"]].describe()
# Out:
#               age        fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
df.agg({"age":["min","max","median","skew"],
        "fare":["min","max","median","mean"],
       })
# Out:
#               age        fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# skew     0.389108         NaN
# mean          NaN   32.204208

# %%
df[["sex","age"]].groupby("sex").mean()
# Out:
#               age
# sex
# female  27.915709
# male    30.726645

# %%
df.groupby("sex").mean(numeric_only=True)
# Out:
#         passengerid  survived    pclass        age     sibsp     parch  \
# sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              fare
# sex
# female  44.479818
# male    25.523893

# %%
df.groupby("sex")["age"].mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
df.groupby(["sex","pclass"])["fare"].mean()
# Out:
# sex     pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: fare, dtype: float64

# %%
df["pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
df.groupby("pclass")["pclass"].size()
# Out:
# pclass
# 1    216
# 2    184
# 3    491
# Name: pclass, dtype: int64

# %%
df.groupby("pclass")["pclass"].count()
# Out:
# pclass
# 1    216
# 2    184
# 3    491
# Name: pclass, dtype: int64

# %% [markdown]
#                                                                                                                    How to reshape the layout of tables?

# %%
df_titanic = pd.read_csv("titanic.csv").rename(columns=str.lower)
df_titanic.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_air = pd.read_csv("air_quality_long.csv")
df_air.head()
# Out:
#         city country                   date.utc location parameter  value  \
# 0  Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
#
#     unit
# 0  µg/m³
# 1  µg/m³
# 2  µg/m³
# 3  µg/m³
# 4  µg/m³

# %%
df_titanic.sort_values(by="age").head()
# Out:
#      passengerid  survived  pclass                             name     sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       age  sibsp  parch  ticket     fare cabin embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
df_titanic.sort_values(by=["age","pclass"],ascending=False).head()
# Out:
#      passengerid  survived  pclass                                  name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
#
#       sex   age  sibsp  parch    ticket     fare cabin embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
no2 = df_air[df_air["parameter"]=="no2"]
no2.head()
# Out:
#        city country                   date.utc location parameter  value  \
# 1825  Paris      FR  2019-06-21 00:00:00+00:00  FR04014       no2   20.0
# 1826  Paris      FR  2019-06-20 23:00:00+00:00  FR04014       no2   21.8
# 1827  Paris      FR  2019-06-20 22:00:00+00:00  FR04014       no2   26.5
# 1828  Paris      FR  2019-06-20 21:00:00+00:00  FR04014       no2   24.9
# 1829  Paris      FR  2019-06-20 20:00:00+00:00  FR04014       no2   21.4
#
#        unit
# 1825  µg/m³
# 1826  µg/m³
# 1827  µg/m³
# 1828  µg/m³
# 1829  µg/m³

# %%
no2_subset = no2.sort_index().groupby(["location"]).head(2)
no2_subset
# Out:
#            city country                   date.utc            location  \
# 1825      Paris      FR  2019-06-21 00:00:00+00:00             FR04014
# 1826      Paris      FR  2019-06-20 23:00:00+00:00             FR04014
# 3501  Antwerpen      BE  2019-06-17 08:00:00+00:00             BETR801
# 3502  Antwerpen      BE  2019-06-17 07:00:00+00:00             BETR801
# 3664     London      GB  2019-06-17 11:00:00+00:00  London Westminster
# 3665     London      GB  2019-06-17 10:00:00+00:00  London Westminster
#
#      parameter  value   unit
# 1825       no2   20.0  µg/m³
# 1826       no2   21.8  µg/m³
# 3501       no2   41.0  µg/m³
# 3502       no2   45.0  µg/m³
# 3664       no2   11.0  µg/m³
# 3665       no2   11.0  µg/m³

# %%
no2_subset.pivot(columns="location",values="value")
# Out:
# location  BETR801  FR04014  London Westminster
# 1825          NaN     20.0                 NaN
# 1826          NaN     21.8                 NaN
# 3501         41.0      NaN                 NaN
# 3502         45.0      NaN                 NaN
# 3664          NaN      NaN                11.0
# 3665          NaN      NaN                11.0

# %%
no2.head()
# Out:
#        city country                   date.utc location parameter  value  \
# 1825  Paris      FR  2019-06-21 00:00:00+00:00  FR04014       no2   20.0
# 1826  Paris      FR  2019-06-20 23:00:00+00:00  FR04014       no2   21.8
# 1827  Paris      FR  2019-06-20 22:00:00+00:00  FR04014       no2   26.5
# 1828  Paris      FR  2019-06-20 21:00:00+00:00  FR04014       no2   24.9
# 1829  Paris      FR  2019-06-20 20:00:00+00:00  FR04014       no2   21.4
#
#        unit
# 1825  µg/m³
# 1826  µg/m³
# 1827  µg/m³
# 1828  µg/m³
# 1829  µg/m³

# %%
no2.pivot(columns="location",values="value").plot()
# Out:
# <AxesSubplot:>

# %%
df_air.pivot_table(values="value",index="parameter",columns="location",aggfunc="mean")
# Out:
# location     BETR801    FR04014  London Westminster
# parameter
# no2        26.950920  29.374284           29.740050
# pm25       23.169492        NaN           13.443568

# %%
df_air.pivot_table(values="value",index="location",columns="parameter")
# Out:
# parameter                 no2       pm25
# location
# BETR801             26.950920  23.169492
# FR04014             29.374284        NaN
# London Westminster  29.740050  13.443568

# %%
df_air.groupby(["parameter","location"]).mean()
# Out:
#                                   value
# parameter location
# no2       BETR801             26.950920
#           FR04014             29.374284
#           London Westminster  29.740050
# pm25      BETR801             23.169492
#           London Westminster  13.443568

# %%
no2_pivoted=no2.pivot(columns="location",values="value").reset_index()
no2_pivoted.head()
# Out:
# location  index  BETR801  FR04014  London Westminster
# 0          1825      NaN     20.0                 NaN
# 1          1826      NaN     21.8                 NaN
# 2          1827      NaN     26.5                 NaN
# 3          1828      NaN     24.9                 NaN
# 4          1829      NaN     21.4                 NaN

# %%
no_2=df_air.melt(id_vars="date.utc")
no_2.head()
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_2672\3670891517.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   no_2=df_air.melt(id_vars="date.utc")
#                     date.utc variable      value
# 0  2019-06-18 06:00:00+00:00     city  Antwerpen
# 1  2019-06-17 08:00:00+00:00     city  Antwerpen
# 2  2019-06-17 07:00:00+00:00     city  Antwerpen
# 3  2019-06-17 06:00:00+00:00     city  Antwerpen
# 4  2019-06-17 05:00:00+00:00     city  Antwerpen

# %%
df_air
# Out:
#            city country                   date.utc            location  \
# 0     Antwerpen      BE  2019-06-18 06:00:00+00:00             BETR801
# 1     Antwerpen      BE  2019-06-17 08:00:00+00:00             BETR801
# 2     Antwerpen      BE  2019-06-17 07:00:00+00:00             BETR801
# 3     Antwerpen      BE  2019-06-17 06:00:00+00:00             BETR801
# 4     Antwerpen      BE  2019-06-17 05:00:00+00:00             BETR801
# ...         ...     ...                        ...                 ...
# 5267     London      GB  2019-04-09 06:00:00+00:00  London Westminster
# 5268     London      GB  2019-04-09 05:00:00+00:00  London Westminster
# 5269     London      GB  2019-04-09 04:00:00+00:00  London Westminster
# 5270     London      GB  2019-04-09 03:00:00+00:00  London Westminster
# 5271     London      GB  2019-04-09 02:00:00+00:00  London Westminster
#
#      parameter  value   unit
# 0         pm25   18.0  µg/m³
# 1         pm25    6.5  µg/m³
# ...

# %%
ns=pd.Series([1,2,3])
ns
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
ns.values
# Out:
# array([1, 2, 3], dtype=int64)

# %%
ns.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
ns = pd.Series([1,2,3],index=["a","b","c"])
ns
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ns["a"]
# Out:
# 1

# %%
ns[["a","b","c"]]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ns[ns>0]
# Out:
# a    1
# b    2
# c    3
# dtype: int64
