# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(filepath_or_buffer=("./HRDataset_v14.csv"),sep=",",header=0).rename(columns=str.lower)
df.head()
# Out:
#               employee_name  empid  marriedid  maritalstatusid  genderid  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    empstatusid  deptid  perfscoreid  fromdiversityjobfairid  salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       managername  managerid recruitmentsource performancescore  \
# ...

# %%
df["sex"]
# Out:
# 0      M
# 1      M
# 2       F
# 3       F
# 4       F
#        ..
# 306    M
# 307     F
# 308     F
# 309     F
# 310     F
# Name: sex, Length: 311, dtype: object

# %%
df.columns
# Out:
# Index(['employee_name', 'empid', 'marriedid', 'maritalstatusid', 'genderid',
#        'empstatusid', 'deptid', 'perfscoreid', 'fromdiversityjobfairid',
#        'salary', 'termd', 'positionid', 'position', 'state', 'zip', 'dob',
#        'sex', 'maritaldesc', 'citizendesc', 'hispaniclatino', 'racedesc',
#        'dateofhire', 'dateoftermination', 'termreason', 'employmentstatus',
#        'department', 'managername', 'managerid', 'recruitmentsource',
#        'performancescore', 'engagementsurvey', 'empsatisfaction',
#        'specialprojectscount', 'lastperformancereview_date', 'dayslatelast30',
#        'absences'],
#       dtype='object')

# %%
#Los dummies en pandas sirven para convertir columnas categoricas en númericas
dummy_sex=pd.get_dummies(df["sex"],prefix="sexo")
dummy_sex.head()
# Out:
#    sexo_F  sexo_M
# 0       0        1
# 1       0        1
# 2       1        0
# 3       1        0
# 4       1        0

# %%
df["sex"]
# Out:
# 0      M
# 1      M
# 2       F
# 3       F
# 4       F
#        ..
# 306    M
# 307     F
# 308     F
# 309     F
# 310     F
# Name: sex, Length: 311, dtype: object

# %%
df=df.drop(["sex"],axis=1)
df
# Out:
#                 employee_name  empid  marriedid  maritalstatusid  genderid  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
df.columns
# Out:
# Index(['employee_name', 'empid', 'marriedid', 'maritalstatusid', 'genderid',
#        'empstatusid', 'deptid', 'perfscoreid', 'fromdiversityjobfairid',
#        'salary', 'termd', 'positionid', 'position', 'state', 'zip', 'dob',
#        'maritaldesc', 'citizendesc', 'hispaniclatino', 'racedesc',
#        'dateofhire', 'dateoftermination', 'termreason', 'employmentstatus',
#        'department', 'managername', 'managerid', 'recruitmentsource',
#        'performancescore', 'engagementsurvey', 'empsatisfaction',
#        'specialprojectscount', 'lastperformancereview_date', 'dayslatelast30',
#        'absences'],
#       dtype='object')

# %%
df.shape
# Out:
# (311, 36)

# %%
dummy_sex.shape
# Out:
# (311, 2)

# %%
df2=pd.concat([df,dummy_sex],axis=1)
df2.head()
# Out:
#               employee_name  empid  marriedid  maritalstatusid  genderid  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    empstatusid  deptid  perfscoreid  fromdiversityjobfairid  salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    recruitmentsource  performancescore engagementsurvey empsatisfaction  \
# ...

# %%
df2["citizendesc"]
# Out:
# 0      US Citizen
# 1      US Citizen
# 2      US Citizen
# 3      US Citizen
# 4      US Citizen
#           ...
# 306    US Citizen
# 307    US Citizen
# 308    US Citizen
# 309    US Citizen
# 310    US Citizen
# Name: citizendesc, Length: 311, dtype: object

# %%
df_2.shape
# Out:
# (311, 37)

# %%
df_2.columns
# Out:
# Index(['employee_name', 'empid', 'marriedid', 'maritalstatusid', 'genderid',
#        'empstatusid', 'deptid', 'perfscoreid', 'fromdiversityjobfairid',
#        'salary', 'termd', 'positionid', 'position', 'state', 'zip', 'dob',
#        'maritaldesc', 'citizendesc', 'hispaniclatino', 'racedesc',
#        'dateofhire', 'dateoftermination', 'termreason', 'employmentstatus',
#        'department', 'managername', 'managerid', 'recruitmentsource',
#        'performancescore', 'engagementsurvey', 'empsatisfaction',
#        'specialprojectscount', 'lastperformancereview_date', 'dayslatelast30',
#        'absences', 'sexo_F', 'sexo_M '],
#       dtype='object')

# %%
#Crear columnas numericas a partir de la columna categorica.
#Eliminar la columna categorica del dataframe
#Unir dataframe con columnas numericas
def creatdummies(df,varname):
    dummy=pd.get_dummies([varname],prefix=varname)
    df=df.drop(varname,axis=1)
    df=pd.concat([df,dummy],axis=1)
#def createdummies(df,varname):
    #dummy=pd.get_dummies([varname],prefix=varname)
    #df=df.drop(varname,axis=1)
    #df=pd.concat([df,dummy],axis=1)
    #return df.head()

# %%
createdummies(df,"recruitmentsource")

# %%
df.head()
# Out:
#               employee_name  empid  marriedid  maritalstatusid  genderid  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    empstatusid  deptid  perfscoreid  fromdiversityjobfairid  salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       managername  managerid recruitmentsource performancescore  \
# ...

# %%
df.loc[:,"dob":"citizendesc"]
# Out:
#           dob maritaldesc citizendesc
# 0    07/10/83      Single  US Citizen
# 1    05/05/75     Married  US Citizen
# 2    09/19/88     Married  US Citizen
# 3    09/27/88     Married  US Citizen
# 4    09/08/89    Divorced  US Citizen
# ..        ...         ...         ...
# 306  05/11/85      Single  US Citizen
# 307  05/04/82      Single  US Citizen
# 308  08/30/79      Single  US Citizen
# 309  02/24/79      Single  US Citizen
# 310  08/17/78     Widowed  US Citizen
#
# [311 rows x 3 columns]
