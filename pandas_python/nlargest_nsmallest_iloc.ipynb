# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(filepath_or_buffer="../Desktop/ciencias_datos/DATASETS/ifood/ifood_df.csv").rename(columns=str.lower)
df.head()
# Out:
#     income  kidhome  teenhome  recency  mntwines  mntfruits  mntmeatproducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    mntfishproducts  mntsweetproducts  mntgoldprods  ...  marital_together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
df.shape
# Out:
# (2205, 39)

# %%
df.iloc[10:20]
# Out:
#      income  kidhome  teenhome  recency  mntwines  mntfruits  mntmeatproducts  \
# 10   7500.0        0         0       59         6         16               11
# 11  63033.0        0         0       82       194         61              480
# 12  59354.0        1         1       53       233          2               53
# 13  17323.0        0         0       38         3         14               17
# 14  82800.0        0         0       23      1006         22              115
# 15  41850.0        1         1       51        53          5               19
# 16  37760.0        0         0       20        84          5               38
# 17  76995.0        0         1       91      1012         80              498
# 18  33812.0        1         0       86         4         17               19
# 19  37040.0        0         0       41        86          2               73
#
#     mntfishproducts  mntsweetproducts  mntgoldprods  ...  marital_together  \
# ...

# %%
df.columns.values
# Out:
# array(['income', 'kidhome', 'teenhome', 'recency', 'mntwines',
#        'mntfruits', 'mntmeatproducts', 'mntfishproducts',
#        'mntsweetproducts', 'mntgoldprods', 'numdealspurchases',
#        'numwebpurchases', 'numcatalogpurchases', 'numstorepurchases',
#        'numwebvisitsmonth', 'acceptedcmp3', 'acceptedcmp4',
#        'acceptedcmp5', 'acceptedcmp1', 'acceptedcmp2', 'complain',
#        'z_costcontact', 'z_revenue', 'response', 'age', 'customer_days',
#        'marital_divorced', 'marital_married', 'marital_single',
#        'marital_together', 'marital_widow', 'education_2n cycle',
#        'education_basic', 'education_graduation', 'education_master',
#        'education_phd', 'mnttotal', 'mntregularprods',
#        'acceptedcmpoverall'], dtype=object)

# %%
df.nlargest(5,"income")
# Out:
#         income  kidhome  teenhome  recency  mntwines  mntfruits  \
# 1872  113734.0        0         0        9         6          2
# 628   105471.0        0         0       36      1009        181
# 238   102692.0        0         0        5       168        148
# 190   102160.0        0         0       54       763         29
# 115   101970.0        0         0       69       722         27
#
#       mntmeatproducts  mntfishproducts  mntsweetproducts  mntgoldprods  ...  \
# 1872                3                1               262             3  ...
# 628               104              202                21           207  ...
# 238               444               32               172           148  ...
# 190               138               76               176            58  ...
# 115               102               44                72           168  ...
#
#       marital_together  marital_widow  education_2n cycle  education_basic  \
# ...

# %%
df.nsmallest(5,"income")
# Out:
#       income  kidhome  teenhome  recency  mntwines  mntfruits  \
# 1225  1730.0        0         0       65         1          1
# 20    2447.0        1         0       42         1          1
# 1499  3502.0        1         0       56         2          1
# 1820  4023.0        1         1       29         5          0
# 1949  4428.0        0         1        0        16          4
#
#       mntmeatproducts  mntfishproducts  mntsweetproducts  mntgoldprods  ...  \
# 1225                3                1                 1             1  ...
# 20               1725                1                 1             1  ...
# 1499                1                0                 0             1  ...
# 1820                1                1                 1             1  ...
# 1949               12                2                 4           321  ...
#
#       marital_together  marital_widow  education_2n cycle  education_basic  \
# ...

# %%
df.nlargest(5,"recency")
# Out:
#       income  kidhome  teenhome  recency  mntwines  mntfruits  \
# 36   42429.0        0         1       99        55          0
# 195  44794.0        0         1       99        54          0
# 427  20130.0        0         0       99         0          6
# 474  46310.0        1         0       99       185          2
# 589  42429.0        0         1       99        55          0
#
#      mntmeatproducts  mntfishproducts  mntsweetproducts  mntgoldprods  ...  \
# 36                 6                2                 0             4  ...
# 195                7                0                 0             4  ...
# 427                3                7                 6            12  ...
# 474               88               15                 5            14  ...
# 589                6                2                 0             4  ...
#
#      marital_together  marital_widow  education_2n cycle  education_basic  \
# ...

# %%
df.nsmallest(5,"recency")
# Out:
#       income  kidhome  teenhome  recency  mntwines  mntfruits  \
# 22   65324.0        0         1        0       384          0
# 61   32474.0        1         1        0        10          0
# 91   47823.0        0         1        0        53          1
# 149  30523.0        2         1        0         5          0
# 330  84835.0        0         0        0       189        104
#
#      mntmeatproducts  mntfishproducts  mntsweetproducts  mntgoldprods  ...  \
# 22               102               21                32             5  ...
# 61                 1                0                 0             0  ...
# 91                 5                2                 1            10  ...
# 149                3                0                 0             5  ...
# 330              379              111               189           218  ...
#
#      marital_together  marital_widow  education_2n cycle  education_basic  \
# ...

# %%
df.columns
# Out:
# Index(['income', 'kidhome', 'teenhome', 'recency', 'mntwines', 'mntfruits',
#        'mntmeatproducts', 'mntfishproducts', 'mntsweetproducts',
#        'mntgoldprods', 'numdealspurchases', 'numwebpurchases',
#        'numcatalogpurchases', 'numstorepurchases', 'numwebvisitsmonth',
#        'acceptedcmp3', 'acceptedcmp4', 'acceptedcmp5', 'acceptedcmp1',
#        'acceptedcmp2', 'complain', 'z_costcontact', 'z_revenue', 'response',
#        'age', 'customer_days', 'marital_divorced', 'marital_married',
#        'marital_single', 'marital_together', 'marital_widow',
#        'education_2n cycle', 'education_basic', 'education_graduation',
#        'education_master', 'education_phd', 'mnttotal', 'mntregularprods',
#        'acceptedcmpoverall'],
#       dtype='object')

# %%
df[["education_basic","education_graduation","education_master","education_phd","income","recency","response"]]
# Out:
#       education_basic  education_graduation  education_master  education_phd  \
# 0                   0                     1                 0              0
# 1                   0                     1                 0              0
# 2                   0                     1                 0              0
# 3                   0                     1                 0              0
# 4                   0                     0                 0              1
# ...               ...                   ...               ...            ...
# 2200                0                     1                 0              0
# 2201                0                     0                 0              1
# 2202                0                     1                 0              0
# 2203                0                     0                 1              0
# 2204                0                     0                 0              1
#
#        income  recency  response
# ...
